# %%
import numpy as np

# Training data: AND gate
X = np.array([0,1])
y = np.array([1,0])

# %%
# Perceptron parameters
weights = np.zeros(2)
bias    = 0
lr      = 0.1           # learning rate
epochs  = 10

# %%
weights.shape
# Out:
# (2,)

# %%
def step(z):
    return 1 if z >= 0 else 0

# %%
for epoch in range(epochs):
    errors = 0
    for xi, yi in zip(X, y):
        z    = np.dot(weights, xi) + bias
        pred = step(z)
        err  = yi - pred            # error
        weights += lr * err * xi    # weight update
        bias    += lr * err
        errors  += int(err != 0)
    print(f"Epoch {epoch+1}: errors={errors}, w={weights}, b={bias:.1f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 5
#       3 for xi, yi in zip(X, y):
#       4     z    = np.dot(weights, xi) + bias
# ----> 5     pred = step(z)
#       6     err  = yi - pred            # error
#       7     weights += lr * err * xi    # weight update
#
# Cell In[4], line 2, in step(z)
#       1 def step(z):
# ----> 2     return 1 if z >= 0 else 0
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
# Test
print("\n--- Predictions ---")
for xi, yi in zip(X, y):
    pred = step(np.dot(weights, xi) + bias)
    print(f"Input {xi} → pred={pred}, actual={yi}")
# Out:
# --- Predictions ---
# Input [0 0] → pred=0, actual=0
# Input [0 1] → pred=0, actual=0
# Input [1 0] → pred=0, actual=0
# Input [1 1] → pred=1, actual=1

# %%
print(weights)
# Out:
# [0.2 0.1]
